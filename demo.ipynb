# %%
from segment import *
from configs import *
from circle_fit import *
import matplotlib.pyplot as plt
from astropy.time import Time
import multiprocessing as mp
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import cv2
import datetime
import pandas as pd
import numpy as np

# %%
image_file = 'images-cycle-22\CAK_19900408T024600_Q1L1b800px.jpg'
corrected_area, cal_area, output_image  = algorithm(
    input_file = image_file, 
    thresh =170, 
    clip_limit=2,
    area_thresh = 1400
)
plt.imshow(cv2.imread(image_file,0), cmap='gray')
plt.show()
plt.imshow(output_image, cmap='gray')
plt.show()
print(corrected_area, cal_area)
# Out:
# 0.032 0.03826611409895554

# %% [markdown]
# ## Solar Cycle 22

# %%
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-22 already exists.
# 100%|██████████| 940/940 [11:21<00:00,  1.38it/s]

# %% [markdown]
# ## Solar Cycle 21

# %%
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-21 already exists.
# 100%|██████████| 1000/1000 [11:29<00:00,  1.45it/s]

# %% [markdown]
# ## Solar Cycle 20

# %%
main()
# Out:
# 100%|██████████| 1000/1000 [14:45<00:00,  1.13it/s]

# %% [markdown]
# # Solar Cycle 19

# %%
main()
# Out:
# 100%|██████████| 999/999 [13:13<00:00,  1.26it/s]

# %% [markdown]
# # Solar cycle 18

# %%
main()
# Out:
# 100%|██████████| 1000/1000 [19:13<00:00,  1.15s/it]

# %% [markdown]
# # Solar cycle 17

# %%
main()
# Out:
# 100%|██████████| 969/969 [12:14<00:00,  1.32it/s]

# %% [markdown]
# ## Solar cycle 16

# %%
main()
# Out:
# 100%|██████████| 989/989 [13:28<00:00,  1.22it/s]
