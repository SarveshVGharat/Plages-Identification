# %%
from segment import *
from configs import *
from circle_fit import *
import matplotlib.pyplot as plt
from astropy.time import Time
import multiprocessing as mp
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import cv2
import datetime
import pandas as pd
import numpy as np

# %%
image_file = 'images-cycle-22/CAK_19900408T024600_Q1L1b800px.jpg'
corrected_area, cal_area, output_image  = algorithm(
    input_file = image_file, 
    thresh = default_binary_thresh, 
    clip_limit = default_clip_limit,
    area_thresh = 2000,
    lower_area_thresh = default_lower_area_thresh
)
plt.imshow(cv2.imread(image_file,0), cmap='gray')
plt.show()
plt.imshow(output_image, cmap='gray')
plt.show()
print(corrected_area, cal_area)
# Out:
# 0.032 0.027333001439526203

# %% [markdown]
# ## Solar Cycle 22

# %% [markdown]
# Set cycle_id to 22 in [configs.py](./configs.py)

# %%
main()

# %% [markdown]
# ## Solar Cycle 21

# %% [markdown]
# Set cycle_id to 21 in [configs.py](./configs.py)

# %%
main()

# %% [markdown]
# ## Solar Cycle 20

# %% [markdown]
# Set cycle_id to 20 in [configs.py](./configs.py)

# %%
main()

# %% [markdown]
# # Solar Cycle 19

# %% [markdown]
# Set cycle_id to 19 in [configs.py](./configs.py)

# %%
main()

# %% [markdown]
# # Solar cycle 18

# %% [markdown]
# Set cycle_id to 18 in [configs.py](./configs.py)

# %%
main()

# %% [markdown]
# # Solar cycle 17

# %% [markdown]
# Set cycle_id to 17 in [configs.py](./configs.py)

# %%
main()

# %% [markdown]
# ## Solar cycle 16

# %% [markdown]
# Set cycle_id to 16 in [configs.py](./configs.py)

# %%
main()
