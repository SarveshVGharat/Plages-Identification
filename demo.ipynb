# %%
from segment import *
from configs import *
from circle_fit import *
import matplotlib.pyplot as plt
from astropy.time import Time
import multiprocessing as mp
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import cv2
import datetime
import pandas as pd
import numpy as np

# %%
image_file = 'images-cycle-22\CAK_19900408T024600_Q1L1b800px.jpg'
corrected_area, cal_area, output_image  = algorithm(
    input_file = image_file, 
    thresh =170, 
    clip_limit=2,
    area_thresh = 1400,
    lower_area_thresh = 0
)
plt.imshow(cv2.imread(image_file,0), cmap='gray')
plt.show()
plt.imshow(output_image, cmap='gray')
plt.show()
print(corrected_area, cal_area)
# Out:
# 0.032 0.03826611409895554

# %% [markdown]
# ## Solar Cycle 22

# %%
#Set area_thresh_value to 5000
#Set cycle_id to 22
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-22 already exists.
# 100%|██████████| 940/940 [10:49<00:00,  1.45it/s]

# %% [markdown]
# ## Solar Cycle 21

# %%
#Set area_thresh_value to 800
#Set cycle_id to 21
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-21 already exists.
# 100%|██████████| 1000/1000 [11:41<00:00,  1.42it/s]

# %% [markdown]
# ## Solar Cycle 20

# %%
#Set area_thresh_value to 12000
#Set cycle_id to 20
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-20 already exists.
# 100%|██████████| 1000/1000 [14:36<00:00,  1.14it/s]

# %% [markdown]
# # Solar Cycle 19

# %%
#Set area_thresh_value to 2000
#Set cycle_id to 17
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-19 already exists.
# 100%|██████████| 999/999 [13:33<00:00,  1.23it/s]

# %% [markdown]
# # Solar cycle 18

# %%
#Set area_thresh_value to 2000
#Set cycle_id to 17
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-18 already exists.
# 100%|██████████| 1000/1000 [19:15<00:00,  1.16s/it]

# %% [markdown]
# # Solar cycle 17

# %%
#Set area_thresh_value to 3000
#Set cycle_id to 17
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-17 already exists.
# 100%|██████████| 969/969 [13:39<00:00,  1.18it/s]

# %% [markdown]
# ## Solar cycle 16

# %%
#Set area_thresh_value to 3000
#Set cycle_id to 16
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-16 already exists.
# 100%|██████████| 989/989 [13:26<00:00,  1.23it/s]
