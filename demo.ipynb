# %%
from segment import *
from configs import *
from circle_fit import *
import matplotlib.pyplot as plt
from astropy.time import Time
import multiprocessing as mp
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import cv2
import datetime
import pandas as pd
import numpy as np

# %%
image_file = 'images-cycle-22/CAK_19900408T024600_Q1L1b800px.jpg'
corrected_area, cal_area, output_image  = algorithm(
    input_file = image_file, 
    thresh =180, 
    clip_limit=2,
    area_thresh = 2000,
    lower_area_thresh = 0
)
plt.imshow(cv2.imread(image_file,0), cmap='gray')
plt.show()
plt.imshow(output_image, cmap='gray')
plt.show()
print(corrected_area, cal_area)
# Out:
# 0.032 0.027333001439526203

# %% [markdown]
# ## Solar Cycle 22

# %%
#Set cycle_id to 22
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-22 already exists.Deleting table and recreating.
# 100%|██████████| 940/940 [1:42:03<00:00,  6.51s/it]

# %% [markdown]
# ## Solar Cycle 21

# %%
#Set cycle_id to 21
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-21 already exists.Deleting table and recreating.
# 100%|██████████| 1000/1000 [1:50:19<00:00,  6.62s/it]

# %% [markdown]
# ## Solar Cycle 20

# %%
#Set cycle_id to 20
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-20 already exists.Deleting table and recreating.
# 100%|██████████| 1000/1000 [2:43:04<00:00,  9.78s/it]

# %% [markdown]
# # Solar Cycle 19

# %%
#Set cycle_id to 19
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-19 already exists.Deleting table and recreating.
# 100%|██████████| 999/999 [1:42:43<00:00,  6.17s/it]

# %% [markdown]
# # Solar cycle 18

# %%
#Set cycle_id to 18
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-18 already exists.Deleting table and recreating.
# 100%|██████████| 1000/1000 [2:53:20<00:00, 10.40s/it]

# %% [markdown]
# # Solar cycle 17

# %%
#Set cycle_id to 17
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-17 already exists.Deleting table and recreating.
# 100%|██████████| 969/969 [2:41:30<00:00, 10.00s/it]

# %% [markdown]
# ## Solar cycle 16

# %%
#Set cycle_id to 16
main()
# Out:
# Table custom-zone-377316.solar_plage_project.cycle-16 already exists.Deleting table and recreating.
# 100%|██████████| 989/989 [2:40:57<00:00,  9.77s/it]
